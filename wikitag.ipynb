# %% [markdown]
# ### Idea
# 1. word2vec => vector for each word
# 2. phrase detection (https://radimrehurek.com/gensim/models/phrases.html)
# 3. (retrain?)
# 4. tag words with NER tags
# 5. simple classification model
#
# ### Other ideas
# 1. create NER tagged wikipedia text by links to pages with wikidata pages (!)
# 2. TFIDF(? or such) to find interesting/important terms
# 3. https://towardsdatascience.com/wikipedia-data-science-working-with-the-worlds-largest-encyclopedia-c08efbac5f5c

# %%
import mwparserfromhell as mwp
import re, json, time
from requests import Session
from hebtokenizer import tokenize
from pprint import pprint
# from cachetools import LFUCache, cached
import pandas as pd
from yaml import load, Loader
from itertools import chain
from more_itertools import split_after, split_when
from collections import Counter
from yap_tools import *
from apis import *

# %%
s = Session()
s.headers={"User-Agent": "WikiTagger/0.0 (alexzabbey@gmail.com) Python/Requests/3.8"}

# %%
def parse_wiki_page(page_title):
    wiki = mwp.parse(get_wp_fulltext(page_title))
    # remove files
    for l in wiki.filter_wikilinks():
        if l.startswith("[[קטגוריה") or l.startswith("[[קובץ"):
            wiki.remove(l)
    # remove extrenal links section
    wiki.remove(wiki.get_sections(matches=r"קישורים חיצוניים"))
    # remove headings
    for h in wiki.filter_headings():
        wiki.remove(h)
    # replace tags with text
    for x in wiki.filter_tags():
        index = wiki.index(x)
        wiki.remove(x)
        wiki.insert(index, x.contents)
    return wiki

wiki = parse_wiki_page("תקומה")
    
# further reading
# photo gallery - https://he.wikipedia.org/wiki/%D7%AA%D7%A7%D7%95%D7%9E%D7%94/
# tables - https://he.wikipedia.org/wiki/%D7%92%D7%9C%D7%A2%D7%93_%D7%A7%D7%9E%D7%97%D7%99
# Out:
# got full wikipedia text from page תקומה

# %%
wiki.text()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-d97c28c50f7d> in <module>
# ----> 1 wiki.text()
#
# ~/.virtualenvs/wikitag/lib/python3.8/site-packages/mwparserfromhell/string_mixin.py in __getattr__(self, attr)
#     110     def __getattr__(self, attr):
#     111         if not hasattr(str, attr):
# --> 112             raise AttributeError("{!r} object has no attribute {!r}".format(
#     113                 type(self).__name__, attr))
#     114         return getattr(self.__unicode__(), attr)
#
# AttributeError: 'Wikicode' object has no attribute 'text'

# %%
with open("tags.yaml", "r", encoding="utf-8") as f:
    tags = load(f, Loader=Loader)
    
for k, v in tags.items():
    if type(v) == list:
        tags[k] = {"include": v, "exclude": None, "not": None}
    else:
        tags[k].setdefault("exclude", None)
        tags[k].setdefault("not", None)
# Out:
# {'PERSON': {'include': ['Q5', 'Q95074'], 'exclude': None, 'not': None},
#  'NORP': {'include': ['Q49773', 'Q1530022', 'Q41710'],
#   'exclude': None,
#   'not': None},
#  'FAC': {'include': ['Q811979', 'Q121359'],
#   'not': ['Q1068715'],
#   'exclude': None},
#  'ORG': {'include': ['Q783794'],
#   'exclude': ['Q2097994', 'Q7210356'],
#   'not': None},
#  'GPE': {'include': ['Q15642541', 'Q486972', 'Q28108'],
#   'exclude': None,
#   'not': None},
#  'LOC': {'include': ['Q27096220'], 'exclude': None, 'not': None},
#  'EVENT': {'include': ['Q13418847', 'Q8065', 'Q1656682', 'Q350604'],
#   'exclude': None,
#   'not': None},
#  'WORK_OF_ART': {'include': ['Q17537576', 'Q732577'],
#   'exclude': ['Q14897293'],
#   'not': ['Q2135465']},
#  'LAW': {'include': ['Q3150005'], 'exclude': None, 'not': None},
#  'LANGUAGE': {'include': ['Q315', 'Q17376908'], 'exclude': None, 'not': None},
#  'DATE': {'include': ['Q577', 'Q3186692', 'Q14795564', 'Q1790144'],
#   'exclude': None,
#   'not': None}}

# %%
titles = [str(l.title) for l in wiki.filter_wikilinks()]
query = f"""SELECT ?item ?tag (COUNT(?superClass) AS ?count) WHERE {{
  VALUES ?title {{
    {" ".join([f'"{t}"@he' for t in titles])}
  }}
  VALUES ?superClass {{
 { " ".join(["wd:"+x for x in  sum([v["include"] for v in tags.values()], [])])}
  }}
  # ?sitelink schema:about ?item;
    schema:isPartOf <https://he.wikipedia.org/>;
    schema:name ?title.
    # ?item wdt:P31/wdt:P279* ?superClass.
   BIND(COALESCE(
    {", ".join(["IF(" + " || ".join([f"?superClass = wd:{q}" for q in v["include"]]) + f', "{k}", 1/0)' for k, v in tags.items()]) }
    ) AS ?tag).
}}
GROUP BY ?item ?tag"""

# %%
print(query)
# Out:
# SELECT ?item ?tag (COUNT(?superClass) AS ?count) WHERE {
#   VALUES ?title {
#     "שבועון"@he "קונדה נאסט (קבוצת מדיה)"@he "דייוויד רמניק"@he "אנגלית אמריקנית"@he "ניו יורק"@he "2017"@he "ארצות הברית"@he "1925"@he "אנגלית"@he "כתב עת"@he "ארצות הברית"@he "ניו יורק"@he "ביקורת אומנות"@he "מסה (חיבור עיוני)"@he "שירה"@he "סיפורת"@he "ניו יורק"@he "קריקטורה"@he "17 בפברואר"@he "1925"@he "21 בפברואר"@he "ניו יורק טיימס"@he "הומור"@he "לייף"@he "1951"@he "מלחמת העולם השנייה"@he "הירושימה"@he "המאה העשרים"@he "המאה העשרים ואחת"@he "אליס מונרו"@he "הארוקי מורקמי"@he "ולדימיר נבוקוב"@he "פיליפ רות"@he "ג'רום דייוויד סלינג'ר"@he "ג'ון אפדייק"@he "ריצ'רד ייטס"@he "שירלי ג'קסון"@he "סוריאליזם"@he "אוונגליזם"@he "תסמונת מינכהאוזן באמצעות שליח"@he "אברהם בורג"@he "ארנסט המינגוויי"@he "מרלון ברנדו"@he "הוליווד"@he "מתמטיקה"@he "ויליאם שון"@he "1951"@he "1987"@he "רוברט גוטליב"@he "1987"@he "1992"@he "טינה בראון"@he "1992"@he "1998"@he "צבע"@he "ניו יורק טיימס"@he "צילום"@he "1985"@he "1998"@he "שנות התשעים"@he "אינטרנט"@he "iPad"@he "מלקולם גלדוול"@he "וולפראם אלפא"@he "2008"@he "2003"@he "קליפורניה"@he "2005"@he "כתב עת"@he "משק הבית"@he "ארצות הברית"@he "פוליטיקה"@he "כתב עת"@he "מפלגה"@he "ארצות הברית"@he "2004"@he "ג'ון קרי"@he "ג'ורג' ווקר בוש"@he "1 בנובמבר"@he "מאמר מערכת"@he "2008"@he "המפלגה הדמוקרטית"@he "ברק אובמה"@he "המפלגה הרפובליקנית"@he "ג'ון מקיין"@he "פיגועי 11 בספטמבר"@he "2001"@he "קריקטוריסט"@he "ארט ספיגלמן"@he "שחור"@he "מגדלי התאומים"@he "אור"@he "סימור הרש"@he "מלחמת עיראק"@he "כלא אבו גרייב"@he "מחלקת ההגנה של ארצות הברית"@he "איראן"@he "קריקטורה"@he "1956"@he "1958"@he "1973"@he "1993"@he "כתב עת"@he "1998"@he "הומור"@he "צ'ארלס אדמס"@he "סול סטיינברג"@he "לייזה דונלי"@he "ויליאם סטייג"@he "איור"@he "רי אירווין"@he "כובע צילינדר"@he "פרפר"@he "מונוקל"@he "קורי פורד"@he "8 באוגוסט"@he "מכנסיים"@he "פראק"@he "מקסיקו"@he "פסיק"@he "מלחציים"@he "כתב נטוי"@he "ים סרגסו"@he "דיונון"@he "דיו"@he "נייר"@he "1882"@he "בד"@he "קמע"@he "21 בפברואר"@he "סול סטיינברג"@he "29 במרץ"@he "1976"@he "מפה"@he "מנהטן"@he "השדרה התשיעית"@he "השדרה העשירית"@he "נהר הדסון"@he "ארצות הברית"@he "ניו יורק"@he "ניו ג'רזי"@he "לוס אנג'לס"@he "וושינגטון די. סי."@he "לאס וגאס"@he "קנזס סיטי"@he "שיקגו"@he "טקסס"@he "יוטה"@he "נברסקה"@he "ניו ג'רזי"@he "האוקיינוס השקט"@he "הרפובליקה העממית של סין"@he "יפן"@he "רוסיה"@he "דימוי עצמי"@he "מוסקבה על ההדסון"@he "1984"@he "זכויות יוצרים"@he "סרטי קולומביה"@he "טרומן קפוטה (סרט)"@he "2005"@he "ידוע לשמצה"@he "2006"@he "פגוש אותי בסנט לואיס"@he "1944"@he "1968"@he "ברט לנקסטר"@he "חטאי מלחמה"@he "בריאן דה פלמה"@he "1989"@he "אדפטיישן"@he "צ'ארלי קאופמן"@he "2002"@he "הר ברוקבק"@he "2005"@he "13 באוקטובר"@he "1997"@he "2007"@he "סיפור קצר"@he "קנדה"@he "2007"@he "אליס מונרו"@he "סיינפלד"@he "משפחת סימפסון"@he "בגידה (זוגיות)"@he "חברים"@he "צ'נדלר בינג"@he "אדפטיישן"@he "2002"@he "גנב הסחלבים"@he "סוזן אורלין"@he "2003"@he "השטן לובשת פראדה"@he "סקס והעיר הגדולה"@he "אנימציה"@he "דן קווייל"@he "פרייז'ר"@he "מבקר מוזיקה"@he "הייקו"@he
#   }
#   VALUES ?superClass {
#  wd:Q5 wd:Q95074 wd:Q49773 wd:Q1530022 wd:Q41710 wd:Q811979 wd:Q121359 wd:Q783794 wd:Q15642541 wd:Q486972 wd:Q28108 wd:Q27096220 wd:Q13418847 wd:Q8065 wd:Q1656682 wd:Q350604 wd:Q17537576 wd:Q732577 wd:Q3150005 wd:Q315 wd:Q17376908 wd:Q577 wd:Q3186692 wd:Q14795564 wd:Q1790144
#   }
#   ?sitelink schema:about ?item;
#     schema:isPartOf <https://he.wikipedia.org/>;
#     schema:name ?title.
#     ?item wdt:P31/wdt:P279* ?superClass.
#    BIND(COALESCE(
#     IF(?superClass = wd:Q5 || ?superClass = wd:Q95074, "PERSON", 1/0), IF(?superClass = wd:Q49773 || ?superClass = wd:Q1530022 || ?superClass = wd:Q41710, "NORP", 1/0), IF(?superClass = wd:Q811979 || ?superClass = wd:Q121359, "FAC", 1/0), IF(?superClass = wd:Q783794, "ORG", 1/0), IF(?superClass = wd:Q15642541 || ?superClass = wd:Q486972 || ?superClass = wd:Q28108, "GPE", 1/0), IF(?superClass = wd:Q27096220, "LOC", 1/0), IF(?superClass = wd:Q13418847 || ?superClass = wd:Q8065 || ?superClass = wd:Q1656682 || ?superClass = wd:Q350604, "EVENT", 1/0), IF(?superClass = wd:Q17537576 || ?superClass = wd:Q732577, "WORK_OF_ART", 1/0), IF(?superClass = wd:Q3150005, "LAW", 1/0), IF(?superClass = wd:Q315 || ?superClass = wd:Q17376908, "LANGUAGE", 1/0), IF(?superClass = wd:Q577 || ?superClass = wd:Q3186692 || ?superClass = wd:Q14795564 || ?superClass = wd:Q1790144, "DATE", 1/0)
#     ) AS ?tag).
# }
# GROUP BY ?item ?tag

# %%
sparql_query(query)
# Out:
# {'head': {'vars': ['item', 'tag', 'count']},
#  'results': {'bindings': [{'item': {'type': 'uri',
#      'value': 'http://www.wikidata.org/entity/Q11934'},
#     'tag': {'type': 'literal', 'value': 'PERSON'},
#     'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}},
#    {'item': {'type': 'uri', 'value': 'http://www.wikidata.org/entity/Q11934'},
#     'tag': {'type': 'literal', 'value': 'WORK_OF_ART'},
#     'count': {'datatype': 'http://www.w3.org/2001/XMLSchema#integer',
#      'type': 'literal',
#      'value': '3'}}]}}

# %%
l = [get_wdid_from_wp(str(t)) for t in [l.title for l in wiki.filter_wikilinks()]]
# Out:
# [False,
#  False,
#  'Q1176307',
#  'Q7976',
#  'Q60',
#  'Q25290',
#  'Q30',
#  'Q18107',
#  'Q1860',
#  'Q41298',
#  'Q30',
#  'Q60',
#  False,
#  'Q35760',
#  'Q482',
#  'Q8253',
#  'Q60',
#  'Q482919',
#  'Q2341',
#  'Q18107',
#  'Q2350',
#  'Q9684',
#  'Q35874',
#  'Q463198',
#  'Q18591',
#  'Q362',
#  'Q34664',
#  False,
#  False,
#  'Q234819',
#  False,
#  'Q36591',
#  'Q187019',
#  'Q79904',
#  'Q105756',
#  'Q544611',
#  'Q239910',
#  'Q39427',
#  'Q194253',
#  'Q1414765',
#  'Q736237',
#  'Q23434',
#  'Q34012',
#  'Q34006',
#  'Q395',
#  False,
#  'Q18591',
#  'Q2429',
#  False,
#  'Q2429',
#  'Q2060',
#  False,
#  'Q2060',
#  'Q2089',
#  'Q1075',
#  'Q9684',
#  'Q11633',
#  'Q2431',
#  'Q2089',
#  False,
#  'Q75',
#  'Q2796',
#  'Q318429',
#  False,
#  'Q2004',
#  'Q1986',
#  'Q99',
#  'Q2019',
#  'Q41298',
#  False,
#  'Q30',
#  'Q7163',
#  'Q41298',
#  'Q7278',
#  'Q30',
#  'Q2014',
#  'Q22316',
#  'Q207',
#  'Q2997',
#  'Q871232',
#  'Q2004',
#  'Q29552',
#  'Q76',
#  'Q29468',
#  'Q10390',
#  'Q10806',
#  'Q1988',
#  'Q3658608',
#  'Q325945',
#  'Q23445',
#  'Q23901739',
#  'Q9128',
#  'Q435792',
#  'Q545449',
#  'Q334740',
#  'Q11209',
#  'Q794',
#  'Q482919',
#  'Q5221',
#  'Q5253',
#  'Q2477',
#  'Q2065',
#  'Q41298',
#  'Q2089',
#  'Q35874',
#  False,
#  'Q432856',
#  'Q6660387',
#  'Q552255',
#  'Q178659',
#  False,
#  'Q110304',
#  False,
#  'Q12721',
#  False,
#  'Q2780',
#  'Q39908',
#  'Q112053',
#  'Q96',
#  'Q161736',
#  'Q475638',
#  'Q344098',
#  'Q169274',
#  False,
#  'Q127418',
#  'Q11472',
#  'Q7812',
#  'Q5295538',
#  'Q131557',
#  'Q2350',
#  'Q432856',
#  'Q2459',
#  'Q2480',
#  'Q4006',
#  'Q11299',
#  'Q130378',
#  'Q130388',
#  False,
#  'Q30',
#  'Q60',
#  'Q1408',
#  'Q65',
#  'Q61',
#  'Q23768',
#  'Q41819',
#  'Q1297',
#  'Q1439',
#  'Q829',
#  'Q1553',
#  'Q1408',
#  'Q98',
#  'Q148',
#  'Q17',
#  'Q159',
#  'Q473596',
#  False,
#  'Q2432',
#  'Q12948581',
#  'Q186941',
#  'Q463615',
#  'Q2019',
#  False,
#  'Q2021',
#  False,
#  'Q5268',
#  'Q2644',
#  'Q160528',
#  False,
#  'Q189526',
#  'Q2425',
#  'Q352431',
#  'Q312751',
#  'Q1987',
#  'Q160618',
#  'Q2019',
#  'Q2925',
#  'Q2088',
#  'Q2024',
#  'Q49084',
#  'Q16',
#  'Q2024',
#  'Q234819',
#  'Q23733',
#  'Q886',
#  'Q2914621',
#  'Q79784',
#  'Q745284',
#  'Q352431',
#  'Q1987',
#  False,
#  False,
#  'Q1986',
#  'Q223316',
#  'Q35791',
#  False,
#  'Q49214',
#  'Q209282',
#  False,
#  'Q37707']

# %%
pd.DataFrame.from_dict(wp_title_to_wdid, orient="index").to_dict()
# Out:
# {0: {('שבועון',): False,
#   ('קונדה נאסט (קבוצת מדיה)',): False,
#   ('דייוויד רמניק',): 'Q1176307',
#   ('אנגלית אמריקנית',): 'Q7976',
#   ('ניו יורק',): 'Q60',
#   ('2017',): 'Q25290',
#   ('ארצות הברית',): 'Q30',
#   ('1925',): 'Q18107',
#   ('אנגלית',): 'Q1860',
#   ('כתב עת',): 'Q41298',
#   ('ביקורת אומנות',): False,
#   ('מסה (חיבור עיוני)',): 'Q35760',
#   ('שירה',): 'Q482',
#   ('סיפורת',): 'Q8253',
#   ('קריקטורה',): 'Q482919',
#   ('17 בפברואר',): 'Q2341',
#   ('21 בפברואר',): 'Q2350',
#   ('ניו יורק טיימס',): 'Q9684',
#   ('הומור',): 'Q35874',
#   ('לייף',): 'Q463198',
#   ('1951',): 'Q18591',
#   ('מלחמת העולם השנייה',): 'Q362',
#   ('הירושימה',): 'Q34664',
#   ('המאה העשרים',): False,
#   ('המאה העשרים ואחת',): False,
#   ('אליס מונרו',): 'Q234819',
#   ('הארוקי מורקמי',): False,
#   ('ולדימיר נבוקוב',): 'Q36591',
#   ('פיליפ רות',): 'Q187019',
#   ("ג'רום דייוויד סלינג'ר",): 'Q79904',
#   ("ג'ון אפדייק",): 'Q105756',
#   ("ריצ'רד ייטס",): 'Q544611',
#   ("שירלי ג'קסון",): 'Q239910',
#   ('סוריאליזם',): 'Q39427',
#   ('אוונגליזם',): 'Q194253',
#   ('תסמונת מינכהאוזן באמצעות שליח',): 'Q1414765',
#   ('אברהם בורג',): 'Q736237',
#   ('ארנסט המינגוויי',): 'Q23434',
#   ('מרלון ברנדו',): 'Q34012',
#   ('הוליווד',): 'Q34006',
#   ('מתמטיקה',): 'Q395',
#   ('ויליאם שון',): False,
#   ('1987',): 'Q2429',
#   ('רוברט גוטליב',): False,
#   ('1992',): 'Q2060',
#   ('טינה בראון',): False,
#   ('1998',): 'Q2089',
#   ('צבע',): 'Q1075',
#   ('צילום',): 'Q11633',
#   ('1985',): 'Q2431',
#   ('שנות התשעים',): False,
#   ('אינטרנט',): 'Q75',
#   ('iPad',): 'Q2796',
#   ('מלקולם גלדוול',): 'Q318429',
#   ('וולפראם אלפא',): False,
#   ('2008',): 'Q2004',
#   ('2003',): 'Q1986',
#   ('קליפורניה',): 'Q99',
#   ('2005',): 'Q2019',
#   ('משק הבית',): False,
#   ('פוליטיקה',): 'Q7163',
#   ('מפלגה',): 'Q7278',
#   ('2004',): 'Q2014',
#   ("ג'ון קרי",): 'Q22316',
#   ("ג'ורג' ווקר בוש",): 'Q207',
#   ('1 בנובמבר',): 'Q2997',
#   ('מאמר מערכת',): 'Q871232',
#   ('המפלגה הדמוקרטית',): 'Q29552',
#   ('ברק אובמה',): 'Q76',
#   ('המפלגה הרפובליקנית',): 'Q29468',
#   ("ג'ון מקיין",): 'Q10390',
#   ('פיגועי 11 בספטמבר',): 'Q10806',
#   ('2001',): 'Q1988',
#   ('קריקטוריסט',): 'Q3658608',
#   ('ארט ספיגלמן',): 'Q325945',
#   ('שחור',): 'Q23445',
#   ('מגדלי התאומים',): 'Q23901739',
#   ('אור',): 'Q9128',
#   ('סימור הרש',): 'Q435792',
#   ('מלחמת עיראק',): 'Q545449',
#   ('כלא אבו גרייב',): 'Q334740',
#   ('מחלקת ההגנה של ארצות הברית',): 'Q11209',
#   ('איראן',): 'Q794',
#   ('1956',): 'Q5221',
#   ('1958',): 'Q5253',
#   ('1973',): 'Q2477',
#   ('1993',): 'Q2065',
#   ("צ'ארלס אדמס",): False,
#   ('סול סטיינברג',): 'Q432856',
#   ('לייזה דונלי',): 'Q6660387',
#   ('ויליאם סטייג',): 'Q552255',
#   ('איור',): 'Q178659',
#   ('רי אירווין',): False,
#   ('כובע צילינדר',): 'Q110304',
#   ('פרפר',): False,
#   ('מונוקל',): 'Q12721',
#   ('קורי פורד',): False,
#   ('8 באוגוסט',): 'Q2780',
#   ('מכנסיים',): 'Q39908',
#   ('פראק',): 'Q112053',
#   ('מקסיקו',): 'Q96',
#   ('פסיק',): 'Q161736',
#   ('מלחציים',): 'Q475638',
#   ('כתב נטוי',): 'Q344098',
#   ('ים סרגסו',): 'Q169274',
#   ('דיונון',): False,
#   ('דיו',): 'Q127418',
#   ('נייר',): 'Q11472',
#   ('1882',): 'Q7812',
#   ('בד',): 'Q5295538',
#   ('קמע',): 'Q131557',
#   ('29 במרץ',): 'Q2459',
#   ('1976',): 'Q2480',
#   ('מפה',): 'Q4006',
#   ('מנהטן',): 'Q11299',
#   ('השדרה התשיעית',): 'Q130378',
#   ('השדרה העשירית',): 'Q130388',
#   ('נהר הדסון',): False,
#   ("ניו ג'רזי",): 'Q1408',
#   ("לוס אנג'לס",): 'Q65',
#   ('וושינגטון די. סי.',): 'Q61',
#   ('לאס וגאס',): 'Q23768',
#   ('קנזס סיטי',): 'Q41819',
#   ('שיקגו',): 'Q1297',
#   ('טקסס',): 'Q1439',
#   ('יוטה',): 'Q829',
#   ('נברסקה',): 'Q1553',
#   ('האוקיינוס השקט',): 'Q98',
#   ('הרפובליקה העממית של סין',): 'Q148',
#   ('יפן',): 'Q17',
#   ('רוסיה',): 'Q159',
#   ('דימוי עצמי',): 'Q473596',
#   ('מוסקבה על ההדסון',): False,
#   ('1984',): 'Q2432',
#   ('זכויות יוצרים',): 'Q12948581',
#   ('סרטי קולומביה',): 'Q186941',
#   ('טרומן קפוטה (סרט)',): 'Q463615',
#   ('ידוע לשמצה',): False,
#   ('2006',): 'Q2021',
#   ('פגוש אותי בסנט לואיס',): False,
#   ('1944',): 'Q5268',
#   ('1968',): 'Q2644',
#   ('ברט לנקסטר',): 'Q160528',
#   ('חטאי מלחמה',): False,
#   ('בריאן דה פלמה',): 'Q189526',
#   ('1989',): 'Q2425',
#   ('אדפטיישן',): 'Q352431',
#   ("צ'ארלי קאופמן",): 'Q312751',
#   ('2002',): 'Q1987',
#   ('הר ברוקבק',): 'Q160618',
#   ('13 באוקטובר',): 'Q2925',
#   ('1997',): 'Q2088',
#   ('2007',): 'Q2024',
#   ('סיפור קצר',): 'Q49084',
#   ('קנדה',): 'Q16',
#   ('סיינפלד',): 'Q23733',
#   ('משפחת סימפסון',): 'Q886',
#   ('בגידה (זוגיות)',): 'Q2914621',
#   ('חברים',): 'Q79784',
#   ("צ'נדלר בינג",): 'Q745284',
#   ('גנב הסחלבים',): False,
#   ('סוזן אורלין',): False,
#   ('השטן לובשת פראדה',): 'Q223316',
#   ('סקס והעיר הגדולה',): 'Q35791',
#   ('אנימציה',): False,
#   ('דן קווייל',): 'Q49214',
#   ("פרייז'ר",): 'Q209282',
#   ('מבקר מוזיקה',): False,
#   ('הייקו',): 'Q37707'}}

# %%
def graphql_query(query):
    # posting to GraphQL server
    res = s.post(
        "https://tools.wmflabs.org/tptools/wdql.php", json={"query": "{" + query + "}"},
    )
    res.raise_for_status()
    return res.json()

# %%
def instance_of(Q_list):
    query = ""
    for Q in Q_list:
        query += (
            f"""{Q}: item(id: "{Q}")"""
            + """ {statements(propertyIds: "P31") { mainsnak { ... on PropertyValueSnak { value { ... on Entity { id }}}}}}
            """
        )

    j = graphql_query(query)
    return {
        k: [i["mainsnak"]["value"]["id"] for i in j["data"][k]["statements"]]
        for k in j["data"].keys()
    }

# %%
def sparql_query(query, labels=False, without_roots=False):
    url = "https://query.wikidata.org/sparql"
    if without_roots:
        query = query.replace("*", "+")
    res = s.get(url, params={"query": query, "format":"json"})
    res.raise_for_status()
    j = res.json()
    var = [var for var in j["head"]["vars"] if "Label" not in var][0]
    if labels:
        result = [(d[var]["value"].split("/")[-1], d[var + "Label"]["value"]) for d in j["results"]["bindings"]]
    else:
        result = list(set([x[var]["value"].split("/")[-1] for x in j["results"]["bindings"]]))
#     if without_roots:
#         result = list(result - set(roots))
    return result

# %%
def get_subclasses(roots, exclude=None):
    # SPARQL
    if roots == None:
        return []
    def build_query(roots):
        return "SELECT ?subclass WHERE { VALUES ?roots { " + " ".join(["wd:"+r for r in roots]) + " } ?subclass wdt:P279* ?roots.}"
    result = sparql_query(build_query(roots))
    if exclude:
        result = set(result) - set(sparql_query(build_query(exclude)))
    return result

# %%
def quick_eval(q):
    query = "SELECT ?superclassLabel ?superclass WHERE { wd:" + q + """ wdt:P279 ?superclass.
      SERVICE wikibase:label { bd:serviceParam wikibase:language "[AUTO_LANGUAGE],en". }
    }"""
    label_query = 'item(id:"'+ q +'") {label(language:"en") { text } }'
    print(graphql_query(label_query)["data"]["item"]["label"]["text"])
    superclasses = sparql_query(query, labels=True)
    d = {}
    for Q, label in superclasses:
        d[(Q, label)] = [k for k, v in tags.items() if Q in v["include"]]
    return d

# %%
def most_popular(l):
    l = [x[1] for x in l]  
    return Counter(l).most_common(1)[0][0]

# %%
def split_df_by_punct(df):
    l = list(split_after(df.to_records(index=False).tolist(), lambda x: x[0][-1] == "."))
    fixed = []
    for sublist in l:
        if sublist[-1][0] == ".": fixed.append(sublist[:-1])
        else:
            sublist[-1] = (list(sublist[-1])[0][:-1], *sublist[-1][1:])
            fixed.append(sublist)
    return fixed

# %% [markdown]
# Get Wikipedia page

# %% [markdown]
# tag all links and save

# %%
def title_to_tag(wiki, tags):
    # wp_title -> wdid -> instance -> tag
    # pair wdid with wp title
    for t in [l.title for l in wiki.filter_wikilinks()]:
        get_wdid_from_wp(str(t))

    Q_list = list(set(wp_title_to_wdid.values()) - {False})
    wdid_to_instance = instance_of(Q_list)
    title_to_instance = {}
    for k, v in wp_title_to_wdid.items():
        if v != False:
            title_to_instance[k[0]] = wdid_to_instance[v]

    tagged_titles = {}
    for title, Q_list in title_to_instance.items():
        options = []
        for Q in Q_list:
            for tag in tags:
                if Q in tags[tag]["not"]:
                    break
                if Q in tags[tag]["include"]:
                    options.append((Q, tag))
        tagged_titles[title] = options
    tagged_titles = {k: most_popular(v) for k, v in tagged_titles.items() if len(v) > 0}

# %%
# pair wdid with wp title
for t in [l.title for l in wiki.filter_wikilinks()]:
    get_wdid_from_wp(str(t))

# %%
Q_list = list(set(wp_title_to_wdid.values()) - {False})
wdid_to_instance = instance_of(Q_list)

# %%
title_to_instance = {}
for k, v in wp_title_to_wdid.items():
    if v != False:
        title_to_instance[k[0]] = wdid_to_instance[v]

pprint(title_to_instance)
# Out:
# {'1 בנובמבר': ['Q14795564'],
#  '13 באוקטובר': ['Q14795564'],
#  '17 בפברואר': ['Q14795564'],
#  '1882': ['Q577'],
#  '1925': ['Q577'],
#  '1944': ['Q577', 'Q19828'],
#  '1951': ['Q577'],
#  '1956': ['Q577', 'Q19828'],
#  '1958': ['Q577'],
#  '1968': ['Q577', 'Q19828'],
#  '1973': ['Q577'],
#  '1976': ['Q577', 'Q217019'],
#  '1984': ['Q577', 'Q19828'],
#  '1985': ['Q577'],
#  '1987': ['Q577'],
#  '1989': ['Q577'],
#  '1992': ['Q577', 'Q19828'],
#  '1993': ['Q577'],
#  '1997': ['Q577'],
#  '1998': ['Q577'],
#  '2001': ['Q235729'],
#  '2002': ['Q235729'],
#  '2003': ['Q235729'],
#  '2004': ['Q19828'],
#  '2005': ['Q235729'],
#  '2006': ['Q235729'],
#  '2007': ['Q235729'],
#  '2008': ['Q19828'],
#  '2017': ['Q235729', 'Q235670'],
#  '21 בפברואר': ['Q14795564'],
#  '29 במרץ': ['Q14795564'],
#  '8 באוגוסט': ['Q14795564'],
#  'iPad': ['Q811701'],
#  'אברהם בורג': ['Q5'],
#  'אדפטיישן': ['Q11424'],
#  'אוונגליזם': ['Q995347'],
#  'אור': [],
#  'איור': [],
#  'אינטרנט': ['Q11224256', 'Q1301371'],
#  'איראן': ['Q6256', 'Q3624078', 'Q672729'],
#  'אליס מונרו': ['Q5'],
#  'אנגלית': ['Q33742', 'Q1288568', 'Q34770'],
#  'אנגלית אמריקנית': ['Q951873', 'Q33742'],
#  'ארט ספיגלמן': ['Q5'],
#  'ארנסט המינגוויי': ['Q5'],
#  'ארצות הברית': ['Q3624078', 'Q6256', 'Q1520223', 'Q5255892', 'Q43702'],
#  'בגידה (זוגיות)': [],
#  'בד': [],
#  'ברט לנקסטר': ['Q5'],
#  'בריאן דה פלמה': ['Q5'],
#  'ברק אובמה': ['Q5'],
#  "ג'ון אפדייק": ['Q5'],
#  "ג'ון מקיין": ['Q5'],
#  "ג'ון קרי": ['Q5'],
#  "ג'ורג' ווקר בוש": ['Q5'],
#  "ג'רום דייוויד סלינג'ר": ['Q5'],
#  'דיו': [],
#  'דייוויד רמניק': ['Q5'],
#  'דימוי עצמי': [],
#  'דן קווייל': ['Q5'],
#  'האוקיינוס השקט': ['Q9430'],
#  'הוליווד': ['Q123705'],
#  'הומור': ['Q483394'],
#  'הייקו': ['Q223393'],
#  'הירושימה': ['Q1749269',
#               'Q65589340',
#               'Q2264924',
#               'Q1637706',
#               'Q1549591',
#               'Q515'],
#  'המפלגה הדמוקרטית': ['Q7278'],
#  'המפלגה הרפובליקנית': ['Q7278'],
#  'הר ברוקבק': ['Q11424'],
#  'הרפובליקה העממית של סין': ['Q3624078',
#                              'Q6256',
#                              'Q842112',
#                              'Q859563',
#                              'Q1520223'],
#  'השדרה העשירית': ['Q83620'],
#  'השדרה התשיעית': ['Q83620'],
#  'השטן לובשת פראדה': ['Q11424'],
#  'וושינגטון די. סי.': ['Q5119', 'Q475050', 'Q1093829', 'Q1549591'],
#  'ויליאם סטייג': ['Q5'],
#  'ולדימיר נבוקוב': ['Q5'],
#  'זכויות יוצרים': ['Q2135465', 'Q1146011'],
#  'חברים': ['Q5398426'],
#  'טקסס': ['Q35657'],
#  'טרומן קפוטה (סרט)': ['Q11424'],
#  'יוטה': ['Q35657'],
#  'ים סרגסו': ['Q165'],
#  'יפן': ['Q3624078', 'Q112099', 'Q6256'],
#  'כובע צילינדר': [],
#  'כלא אבו גרייב': ['Q40357', 'Q683992'],
#  'כתב נטוי': [],
#  'כתב עת': [],
#  'לאס וגאס': ['Q1549591', 'Q1093829', 'Q56061'],
#  "לוס אנג'לס": ['Q13218391', 'Q62049', 'Q1093829', 'Q1549591', 'Q1637706'],
#  'לייזה דונלי': ['Q5'],
#  'לייף': ['Q41298'],
#  'מאמר מערכת': ['Q4894405'],
#  'מגדלי התאומים': ['Q19934856'],
#  'מונוקל': [],
#  'מחלקת ההגנה של ארצות הברית': ['Q1788820', 'Q910252'],
#  'מכנסיים': [],
#  'מלחמת העולם השנייה': ['Q103495'],
#  'מלחמת עיראק': ['Q198'],
#  'מלחציים': [],
#  'מלקולם גלדוול': ['Q5'],
#  'מנהטן': ['Q1066984', 'Q408804'],
#  'מסה (חיבור עיוני)': ['Q223393', 'Q4263830'],
#  'מפה': ['Q41362222'],
#  'מפלגה': [],
#  'מקסיקו': ['Q3624078', 'Q6256'],
#  'מרלון ברנדו': ['Q5'],
#  'משפחת סימפסון': ['Q581714', 'Q21188110'],
#  'מתמטיקה': ['Q11862829', 'Q4671286', 'Q41511'],
#  'נברסקה': ['Q35657'],
#  "ניו ג'רזי": ['Q35657'],
#  'ניו יורק': ['Q208511',
#               'Q2264924',
#               'Q1093829',
#               'Q515',
#               'Q1549591',
#               'Q51929311',
#               'Q1637706'],
#  'ניו יורק טיימס': ['Q1110794', 'Q1153191'],
#  'נייר': [],
#  'סול סטיינברג': ['Q5'],
#  'סוריאליזם': ['Q968159'],
#  'סיינפלד': ['Q5398426'],
#  'סימור הרש': ['Q5'],
#  'סיפור קצר': ['Q223393', 'Q4263830'],
#  'סיפורת': ['Q483394'],
#  'סקס והעיר הגדולה': ['Q5398426'],
#  'סרטי קולומביה': ['Q1762059', 'Q368290'],
#  'פוליטיקה': ['Q483394'],
#  'פיגועי 11 בספטמבר': ['Q217327', 'Q898712', 'Q750215', 'Q2223653'],
#  'פיליפ רות': ['Q5'],
#  'פסיק': ['Q1668151'],
#  'פראק': [],
#  "פרייז'ר": ['Q5398426'],
#  "צ'ארלי קאופמן": ['Q5'],
#  "צ'נדלר בינג": ['Q15632617', 'Q15773317'],
#  'צבע': ['Q4373292', 'Q214609'],
#  'צילום': ['Q2695280', 'Q735', 'Q11862829'],
#  'קליפורניה': ['Q35657'],
#  'קמע': [],
#  'קנדה': ['Q223832', 'Q202686', 'Q3624078', 'Q6256'],
#  'קנזס סיטי': ['Q1093829', 'Q1549591'],
#  'קריקטורה': ['Q1792379'],
#  'קריקטוריסט': ['Q28640'],
#  'רוסיה': ['Q3624078',
#            'Q859563',
#            'Q4209223',
#            'Q619610',
#            'Q185145',
#            'Q6256',
#            'Q1323642'],
#  "ריצ'רד ייטס": ['Q5'],
#  'שחור': ['Q1075', 'Q166902', 'Q56053097', 'Q56053556'],
#  'שיקגו': ['Q1093829', 'Q1637706', 'Q1549591'],
#  'שירה': ['Q223393'],
#  "שירלי ג'קסון": ['Q5'],
#  'תסמונת מינכהאוזן באמצעות שליח': ['Q12136']}

# %%
with open("tags.yaml", "r", encoding="utf-8") as f:
    tags = load(f, Loader=Loader)

# %%
wp_title_to_wdid
# Out:
# {('שבועון'): False,
#  ('קונדה נאסט (קבוצת מדיה)'): False,
#  ('דייוויד רמניק'): 'Q1176307',
#  ('אנגלית אמריקנית'): 'Q7976',
#  ('ניו יורק'): 'Q60',
#  ('2017'): 'Q25290',
#  ('ארצות הברית'): 'Q30',
#  ('1925'): 'Q18107',
#  ('אנגלית'): 'Q1860',
#  ('כתב עת'): 'Q41298',
#  ('ביקורת אומנות'): False,
#  ('מסה (חיבור עיוני)'): 'Q35760',
#  ('שירה'): 'Q482',
#  ('סיפורת'): 'Q8253',
#  ('קריקטורה'): 'Q482919',
#  ('17 בפברואר'): 'Q2341',
#  ('21 בפברואר'): 'Q2350',
#  ('ניו יורק טיימס'): 'Q9684',
#  ('הומור'): 'Q35874',
#  ('לייף'): 'Q463198',
#  ('1951'): 'Q18591',
#  ('מלחמת העולם השנייה'): 'Q362',
#  ('הירושימה'): 'Q34664',
#  ('המאה העשרים'): False,
#  ('המאה העשרים ואחת'): False,
#  ('אליס מונרו'): 'Q234819',
#  ('הארוקי מורקמי'): False,
#  ('ולדימיר נבוקוב'): 'Q36591',
#  ('פיליפ רות'): 'Q187019',
#  ("ג'רום דייוויד סלינג'ר"): 'Q79904',
#  ("ג'ון אפדייק"): 'Q105756',
#  ("ריצ'רד ייטס"): 'Q544611',
#  ("שירלי ג'קסון"): 'Q239910',
#  ('סוריאליזם'): 'Q39427',
#  ('אוונגליזם'): 'Q194253',
#  ('תסמונת מינכהאוזן באמצעות שליח'): 'Q1414765',
#  ('אברהם בורג'): 'Q736237',
#  ('ארנסט המינגוויי'): 'Q23434',
#  ('מרלון ברנדו'): 'Q34012',
#  ('הוליווד'): 'Q34006',
#  ('מתמטיקה'): 'Q395',
#  ('ויליאם שון'): False,
#  ('1987'): 'Q2429',
#  ('רוברט גוטליב'): False,
#  ('1992'): 'Q2060',
#  ('טינה בראון'): False,
#  ('1998'): 'Q2089',
#  ('צבע'): 'Q1075',
#  ('צילום'): 'Q11633',
#  ('1985'): 'Q2431',
#  ('שנות התשעים'): False,
#  ('אינטרנט'): 'Q75',
#  ('iPad'): 'Q2796',
#  ('מלקולם גלדוול'): 'Q318429',
#  ('וולפראם אלפא'): False,
#  ('2008'): 'Q2004',
#  ('2003'): 'Q1986',
#  ('קליפורניה'): 'Q99',
#  ('2005'): 'Q2019',
#  ('משק הבית'): False,
#  ('פוליטיקה'): 'Q7163',
#  ('מפלגה'): 'Q7278',
#  ('2004'): 'Q2014',
#  ("ג'ון קרי"): 'Q22316',
#  ("ג'ורג' ווקר בוש"): 'Q207',
#  ('1 בנובמבר'): 'Q2997',
#  ('מאמר מערכת'): 'Q871232',
#  ('המפלגה הדמוקרטית'): 'Q29552',
#  ('ברק אובמה'): 'Q76',
#  ('המפלגה הרפובליקנית'): 'Q29468',
#  ("ג'ון מקיין"): 'Q10390',
#  ('פיגועי 11 בספטמבר'): 'Q10806',
#  ('2001'): 'Q1988',
#  ('קריקטוריסט'): 'Q3658608',
#  ('ארט ספיגלמן'): 'Q325945',
#  ('שחור'): 'Q23445',
#  ('מגדלי התאומים'): 'Q23901739',
#  ('אור'): 'Q9128',
#  ('סימור הרש'): 'Q435792',
#  ('מלחמת עיראק'): 'Q545449',
#  ('כלא אבו גרייב'): 'Q334740',
#  ('מחלקת ההגנה של ארצות הברית'): 'Q11209',
#  ('איראן'): 'Q794',
#  ('1956'): 'Q5221',
#  ('1958'): 'Q5253',
#  ('1973'): 'Q2477',
#  ('1993'): 'Q2065',
#  ("צ'ארלס אדמס"): False,
#  ('סול סטיינברג'): 'Q432856',
#  ('לייזה דונלי'): 'Q6660387',
#  ('ויליאם סטייג'): 'Q552255',
#  ('איור'): 'Q178659',
#  ('רי אירווין'): False,
#  ('כובע צילינדר'): 'Q110304',
#  ('פרפר'): False,
#  ('מונוקל'): 'Q12721',
#  ('קורי פורד'): False,
#  ('8 באוגוסט'): 'Q2780',
#  ('מכנסיים'): 'Q39908',
#  ('פראק'): 'Q112053',
#  ('מקסיקו'): 'Q96',
#  ('פסיק'): 'Q161736',
#  ('מלחציים'): 'Q475638',
#  ('כתב נטוי'): 'Q344098',
#  ('ים סרגסו'): 'Q169274',
#  ('דיונון'): False,
#  ('דיו'): 'Q127418',
#  ('נייר'): 'Q11472',
#  ('1882'): 'Q7812',
#  ('בד'): 'Q5295538',
#  ('קמע'): 'Q131557',
#  ('29 במרץ'): 'Q2459',
#  ('1976'): 'Q2480',
#  ('מפה'): 'Q4006',
#  ('מנהטן'): 'Q11299',
#  ('השדרה התשיעית'): 'Q130378',
#  ('השדרה העשירית'): 'Q130388',
#  ('נהר הדסון'): False,
#  ("ניו ג'רזי"): 'Q1408',
#  ("לוס אנג'לס"): 'Q65',
#  ('וושינגטון די. סי.'): 'Q61',
#  ('לאס וגאס'): 'Q23768',
#  ('קנזס סיטי'): 'Q41819',
#  ('שיקגו'): 'Q1297',
#  ('טקסס'): 'Q1439',
#  ('יוטה'): 'Q829',
#  ('נברסקה'): 'Q1553',
#  ('האוקיינוס השקט'): 'Q98',
#  ('הרפובליקה העממית של סין'): 'Q148',
#  ('יפן'): 'Q17',
#  ('רוסיה'): 'Q159',
#  ('דימוי עצמי'): 'Q473596',
#  ('מוסקבה על ההדסון'): False,
#  ('1984'): 'Q2432',
#  ('זכויות יוצרים'): 'Q12948581',
#  ('סרטי קולומביה'): 'Q186941',
#  ('טרומן קפוטה (סרט)'): 'Q463615',
#  ('ידוע לשמצה'): False,
#  ('2006'): 'Q2021',
#  ('פגוש אותי בסנט לואיס'): False,
#  ('1944'): 'Q5268',
#  ('1968'): 'Q2644',
#  ('ברט לנקסטר'): 'Q160528',
#  ('חטאי מלחמה'): False,
#  ('בריאן דה פלמה'): 'Q189526',
#  ('1989'): 'Q2425',
#  ('אדפטיישן'): 'Q352431',
#  ("צ'ארלי קאופמן"): 'Q312751',
#  ('2002'): 'Q1987',
#  ('הר ברוקבק'): 'Q160618',
#  ('13 באוקטובר'): 'Q2925',
#  ('1997'): 'Q2088',
#  ('2007'): 'Q2024',
#  ('סיפור קצר'): 'Q49084',
#  ('קנדה'): 'Q16',
#  ('סיינפלד'): 'Q23733',
#  ('משפחת סימפסון'): 'Q886',
#  ('בגידה (זוגיות)'): 'Q2914621',
#  ('חברים'): 'Q79784',
#  ("צ'נדלר בינג"): 'Q745284',
#  ('גנב הסחלבים'): False,
#  ('סוזן אורלין'): False,
#  ('השטן לובשת פראדה'): 'Q223316',
#  ('סקס והעיר הגדולה'): 'Q35791',
#  ('אנימציה'): False,
#  ('דן קווייל'): 'Q49214',
#  ("פרייז'ר"): 'Q209282',
#  ('מבקר מוזיקה'): False,
#  ('הייקו'): 'Q37707'}

# %%
for k, v in tags.items():
    if type(v) == list:
        tags[k] = {"include": v, "exclude": None, "not": None}
    else:
        tags[k].setdefault("exclude", None)
        tags[k].setdefault("not", None)

for k, v in tags.items():
    tags[k]["include"] = get_subclasses(v["include"], exclude=v["exclude"])
    tags[k]["not"] = get_subclasses(v["not"])

# %%
tagged_titles = {}
for title, Q_list in title_to_instance.items():
    options = []
    for Q in Q_list:
        for tag in tags:
            if Q in tags[tag]["not"]:
                break
            if Q in tags[tag]["include"]:
                options.append((Q, tag))
    tagged_titles[title] = options
pprint(tagged_titles)

tagged_titles = {k: most_popular(v) for k, v in tagged_titles.items() if len(v) > 0}

# %%
final_df
# Out:
#      untokenized_word         tag
# 0                הניו           O
# 1               יורקר           O
# 2                  (ב           O
# 3              אנגלית  B-LANGUAGE
# 4                   :           O
# ...               ...         ...
# 2260               של           O
# 2261              כתב           O
# 2262             הניו           O
# 2263            יורקר           O
# 2264            (RSS)           O
#
# [2265 rows x 2 columns]

# %%
def tokenize_df(df):
    ht = HebTokenizer()
    extra_columns = set(df.columns.tolist()
    print(extra_columns)
    df["untokenized_word"] = df["untokenized_word"].apply(ht.tokenize)
    df = df.explode("untokenized_word")
    df[["word", "token"]] = pd.DataFrame(
        df["untokenized_word"].tolist(), index=df.index
    )
    return df[["word", *extra_columns, "token"]].reset_index(drop=True)

# %%
pd.DataFrame.from_dict(tags)
# Out:
#                                                     PERSON  \
# include  [Q42301900, Q8031410, Q4306757, Q2662735, Q557...
# exclude                                               None
# not                                                     []
#
#                                                       NORP  \
# include  [Q57413580, Q1184788, Q12347356, Q359882, Q238...
# exclude                                               None
# not                                                     []
#
#                                                        FAC  \
# include  [Q6390435, Q12745000, Q73998508, Q3758835, Q25...
# exclude                                               None
# not      [Q28754053, Q1360517, Q36509592, Q11347580, Q8...
#
#                                                        ORG  \
# include  {Q12540664, Q3488704, Q57655560, Q18411470, Q1...
# exclude                               [Q2097994, Q7210356]
# not                                                     []
#
#                                                        GPE  \
# include  [Q182875, Q15092269, Q206824, Q282587, Q548317...
# exclude                                               None
# not                                                     []
#
#                                                        LOC  \
# include  [Q9200005, Q3031290, Q1805497, Q755017, Q13516...
# exclude                                               None
# not                                                     []
#
#                                                      EVENT  \
# include  [Q21697714, Q60221005, Q3621221, Q1139274, Q18...
# exclude                                               None
# not                                                     []
#
#                                                WORK_OF_ART  \
# include  {Q65464693, Q6390435, Q62586083, Q65179965, Q6...
# exclude                                        [Q14897293]
# not      [Q20755435, Q712597, Q9638611, Q255232, Q22569...
#
#                                                        LAW  \
# include  [Q20755435, Q712597, Q255232, Q2256985, Q20727...
# exclude                                               None
# not                                                     []
#
#                                                   LANGUAGE  \
# include  [Q11002922, Q833796, Q3192221, Q7007228, Q7377...
# exclude                                               None
# not                                                     []
#
#                                                       DATE
# include  [Q235684, Q7452865, Q15629794, Q630830, Q13004...
# exclude                                               None
# not                                                     []

# %%
import re
scanner = re.Scanner([
    ('whitespace', r'\s+'),
    ('plus', r'\+'),
    ('minus', r'\-'),
    ('mult', r'\*'),
    ('div', r'/'),
    ('num', r'\d+'),
    ('paren_open', r'\('),
    ('paren_close', r'\)'),
])

for token, match in scanner.scan('(1 + 2) * 3'):
    print (token, match.group())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-179-b5529be4380c> in <module>
#      11 ])
#      12
# ---> 13 for token, match in scanner.scan('(1 + 2) * 3'):
#      14     print (token, match.group())
#
# ValueError: not enough values to unpack (expected 2, got 0)

# %%
tokenize_df(final_df)
# Out:
# untokenized_word
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-178-c6b1aee3a638> in <module>
# ----> 1 tokenize_df(final_df)
#
# <ipython-input-177-2f05a7093f72> in tokenize_df(df)
#       5     df["untokenized_word"] = df["untokenized_word"].apply(ht.tokenize)
#       6     df = df.explode("untokenized_word")
# ----> 7     df[["word", "token"]] = pd.DataFrame(
#       8         df["untokenized_word"].tolist(), index=df.index
#       9     )
#
# ~/.virtualenvs/wikitag/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3482             self._setitem_frame(key, value)
#    3483         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3484             self._setitem_array(key, value)
#    3485         else:
#    3486             # set column
#
# ~/.virtualenvs/wikitag/lib/python3.8/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3505             if isinstance(value, DataFrame):
#    3506                 if len(value.columns) != len(key):
# -> 3507                     raise ValueError("Columns must be same length as key")
#    3508                 for k1, k2 in zip(key, value.columns):
#    3509                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key

# %%
with open("tagged_titles.json", "w", encoding="utf-8") as fp:
    json.dump(tagged_titles, fp, ensure_ascii=False)

# %%
from datetime import datetime
now = "now"
print(f"now is {datetime.now()}")
print(now)
# Out:
# now is 2020-01-21 14:17:30.608723
# now

# %%
text = " ".join([s.strip() for s in str.splitlines(wiki.strip_code()) if len(s.strip()) > 0])

# %%
df_list = []
for i, sent in enumerate(text.split(". ")):
    yapped = yap_it(sent + ".")
    time.sleep(3)
    df_list.append(pd_lattice(yapped["md_lattice"]))
    if i > 10:
        break 
word_and_pos = pd.concat(df_list)

# %%
def tag_wikilink(wl):
    tagged_list = []
    tag = tagged_titles.get(str(wl.title), "O")
    text = str(wl.text).split() if wl.text else str(wl.title).split()
    tags = [f"B-{tag}"] + [f"I-{tag}"] * len(text) if tag != "O" else [tag] * len(text)
    return zip(text, tags)

# %%
final = []
for i, n in enumerate(wiki.nodes):
    if not isinstance(n, mwp.nodes.template.Template):
        if isinstance(n, mwp.nodes.text.Text):
            for x in n.split():
                final.append((x, "O"))
        elif isinstance(n, mwp.nodes.wikilink.Wikilink):
            final += tag_wikilink(n)

# %%
final_df = pd.DataFrame(final, columns=["untokenized_word", "tag"])
final_df
# Out:
#      untokenized_word         tag
# 0                הניו           O
# 1               יורקר           O
# 2                  (ב           O
# 3              אנגלית  B-LANGUAGE
# 4                   :           O
# ...               ...         ...
# 2260               של           O
# 2261              כתב           O
# 2262             הניו           O
# 2263            יורקר           O
# 2264            (RSS)           O
#
# [2265 rows x 2 columns]

# %%
ht = HebTokenizer()
final_df["untokenized_word"] = final_df["untokenized_word"].apply(ht.tokenize)
final_df = final_df.explode("untokenized_word")
final_df[["token", "word"]] = pd.DataFrame(final_df["untokenized_word"].tolist(), index=final_df.index)
final_df = final_df[["word", "tag", "token"]].reset_index(drop=True)
# only_tagged_records = [[y for y in x if y[1] != "O"] for x in split_df_by_punct(final_df)]

# %%
("a", "b")[::-1]
# Out:
# ('b', 'a')

# %%
# final_df.to_csv("wikitagged.csv", index=False, encoding="utf-8-sig")
word_and_pos.to_csv("yapped.csv", index=False, encoding="utf-8-sig")

# %%
ht = HebTokenizer()
tokenized_df = pd.DataFrame(ht.tokenize(text), columns=["tag", "word"])[["word", "tag"]]
split_tokenized_df = split_df_by_punct(tokenized_df)

# %%
def split_BIO(x, y):
    return True if (x[1][0] == "B" and y[1][0] == "B") or (x[1][0] == "I" and y[1][0] == "B") else False

# %%
final_final = []
for sent, tagged in zip(split_df_by_punct(tokenized_df), only_tagged_records):
    grouped = list(split_when(tagged, split_BIO))
    found = {}
    last = -1
    for w in grouped:
        for i, word in enumerate(sent):
            if w[0][0] in word[0] and i > last:
                if len(w) > 1:
                    for ii, z in enumerate(w):
                        found[i + ii] = z[1]
                else:
                    found[i] = w[0][1]
                last = i
                break
    indexed = pd.DataFrame.from_dict(found, orient="index", columns=["tag"])
    final_final.append(pd.DataFrame(sent + [(".", "PUNCT")], columns=["word", "tokenized_as"])
                         .join(indexed)
                         .fillna("O")
                      )

pd.concat(final_final).to_csv("final_final.csv", encoding="utf-8-sig")
